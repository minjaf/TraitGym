# %%
import numpy as np
import pandas as pd

# %%
model_metadata = pd.read_csv("../../config/models.csv")
palette = model_metadata.set_index("description")["color"].to_dict()
model_renaming = model_metadata.set_index("name")["description"].to_dict()
model_metadata
# Out:
#                      name   description color
# 0                    CADD          CADD    C0
# 1                 GPN-MSA       GPN-MSA    C1
# 2                  Borzoi        Borzoi    C2
# 3                Enformer      Enformer    C3
# 4                     GPN  gLM-Promoter    C4
# 5   NucleotideTransformer            NT    C5
# 6                HyenaDNA      HyenaDNA    C6
# 7                Caduceus      Caduceus    C7
# 8     CADD+GPN-MSA+Borzoi      Ensemble    C8
# 9                     Sei           Sei    C9
# 10              GPN_final  gLM-Promoter    C4

# %%
dataset_renaming = {
    "mendelian_traits_matched_9": "Mendelian traits",
    "complex_traits_matched_9": "Complex traits",
}

subset_renaming = {}

score_renaming = {
    "LLR.minus.score": "LLR",
    "absLLR.plus.score": "abs(LLR)",
    "Embeddings.plus.euclidean_distance": "L2 dist.",
    "Embeddings.plus.cosine_distance": "Cosine dist.",
    "Embeddings.minus.inner_product": "Inner prod.",
}

# %%
datasets = [
    "mendelian_traits_matched_9",
    "complex_traits_matched_9",
]

subsets = [
    "all",
]

models = [
    "GPN-MSA",
    "GPN_final",
    "NucleotideTransformer",
    "HyenaDNA",
    "Caduceus",
]

scores = [
    "LLR.minus.score",
    "absLLR.plus.score",
    "Embeddings.plus.euclidean_distance",
    "Embeddings.plus.cosine_distance",
    "Embeddings.minus.inner_product",
]

def get_model_path(model, score, dataset, subset):
    return f"../../results/dataset/{dataset}/AUPRC_by_chrom_weighted_average/{subset}/{model}_{score}.csv"

# %%
rows = []
for dataset in datasets:
    for subset in subsets:
        for model in models:
            for score in scores:
                path = get_model_path(model, score, dataset, subset)
                df = pd.read_csv(path).iloc[0]
                rows.append([
                    dataset_renaming.get(dataset, dataset),
                    subset_renaming.get(subset, subset),
                    model_renaming.get(model, model),
                    score_renaming.get(score, score),
                    df["score"],
                    df["se"],
                ])
df = pd.DataFrame(rows, columns=["dataset", "subset", "model", "score", "AUPRC", "se"])
df
# Out:
#              dataset subset         model         score     AUPRC        se
# 0   Mendelian traits    all       GPN-MSA           LLR  0.694475  0.041907
# 1   Mendelian traits    all       GPN-MSA      abs(LLR)  0.654223  0.044973
# 2   Mendelian traits    all       GPN-MSA      L2 dist.  0.206924  0.020884
# 3   Mendelian traits    all       GPN-MSA  Cosine dist.  0.208002  0.020988
# 4   Mendelian traits    all       GPN-MSA   Inner prod.  0.301125  0.031690
# 5   Mendelian traits    all  gLM-Promoter           LLR  0.421676  0.069664
# 6   Mendelian traits    all  gLM-Promoter      abs(LLR)  0.378816  0.068633
# 7   Mendelian traits    all  gLM-Promoter      L2 dist.  0.344996  0.056300
# 8   Mendelian traits    all  gLM-Promoter  Cosine dist.  0.263391  0.038219
# 9   Mendelian traits    all  gLM-Promoter   Inner prod.  0.169318  0.047518
# 10  Mendelian traits    all            NT           LLR  0.119961  0.005964
# 11  Mendelian traits    all            NT      abs(LLR)  0.098064  0.006411
# 12  Mendelian traits    all            NT      L2 dist.  0.187644  0.022908
# 13  Mendelian traits    all            NT  Cosine dist.  0.185598  0.022145
# 14  Mendelian traits    all            NT   Inner prod.  0.184916  0.038922
# 15  Mendelian traits    all      HyenaDNA           LLR  0.115205  0.006084
# 16  Mendelian traits    all      HyenaDNA      abs(LLR)  0.106483  0.005712
# 17  Mendelian traits    all      HyenaDNA      L2 dist.  0.116893  0.014477
# 18  Mendelian traits    all      HyenaDNA  Cosine dist.  0.116403  0.013541
# 19  Mendelian traits    all      HyenaDNA   Inner prod.  0.164817  0.031015
# 20  Mendelian traits    all      Caduceus           LLR  0.107708  0.005421
# 21  Mendelian traits    all      Caduceus      abs(LLR)  0.087799  0.005566
# 22  Mendelian traits    all      Caduceus      L2 dist.  0.134898  0.009045
# 23  Mendelian traits    all      Caduceus  Cosine dist.  0.134559  0.010093
# 24  Mendelian traits    all      Caduceus   Inner prod.  0.131076  0.016255
# 25    Complex traits    all       GPN-MSA           LLR  0.212286  0.009691
# 26    Complex traits    all       GPN-MSA      abs(LLR)  0.223643  0.009396
# 27    Complex traits    all       GPN-MSA      L2 dist.  0.150157  0.006486
# 28    Complex traits    all       GPN-MSA  Cosine dist.  0.150226  0.006510
# 29    Complex traits    all       GPN-MSA   Inner prod.  0.176527  0.009632
# 30    Complex traits    all  gLM-Promoter           LLR  0.112302  0.003315
# 31    Complex traits    all  gLM-Promoter      abs(LLR)  0.109684  0.004063
# 32    Complex traits    all  gLM-Promoter      L2 dist.  0.126253  0.004143
# 33    Complex traits    all  gLM-Promoter  Cosine dist.  0.126480  0.003299
# 34    Complex traits    all  gLM-Promoter   Inner prod.  0.124610  0.004276
# 35    Complex traits    all            NT           LLR  0.100768  0.002226
# 36    Complex traits    all            NT      abs(LLR)  0.099983  0.002484
# 37    Complex traits    all            NT      L2 dist.  0.117851  0.004587
# 38    Complex traits    all            NT  Cosine dist.  0.119393  0.004889
# 39    Complex traits    all            NT   Inner prod.  0.135522  0.005529
# 40    Complex traits    all      HyenaDNA           LLR  0.109734  0.003578
# 41    Complex traits    all      HyenaDNA      abs(LLR)  0.110800  0.003108
# 42    Complex traits    all      HyenaDNA      L2 dist.  0.102096  0.004941
# 43    Complex traits    all      HyenaDNA  Cosine dist.  0.101709  0.004492
# 44    Complex traits    all      HyenaDNA   Inner prod.  0.117746  0.003630
# 45    Complex traits    all      Caduceus           LLR  0.098274  0.001875
# 46    Complex traits    all      Caduceus      abs(LLR)  0.097118  0.001969
# 47    Complex traits    all      Caduceus      L2 dist.  0.114716  0.003663
# 48    Complex traits    all      Caduceus  Cosine dist.  0.115082  0.003761
# 49    Complex traits    all      Caduceus   Inner prod.  0.116676  0.006249

# %%
def format_score(x):
    return (x * 100).round().astype(int).apply(lambda y: f"{y:02d}")

def format_se(x):
    assert (x * 100).max() < 100
    return (x * 100).round().astype(int).apply(lambda y: f"{y:02d}")

#df["value"] = format_score(df.score) + "$\pm$" + format_se(df.se)
#df["value"] = format_score(df.score)
#df["value"] = df.score.apply(lambda x: f"{x:.2f}") + "$\pm$" + df.se.apply(lambda x: f"{x:.2f}")
df["value"] = df.AUPRC.apply(lambda x: f"{x:.3f}")
df
# Out:
#              dataset subset         model         score     AUPRC        se  \
# 0   Mendelian traits    all       GPN-MSA           LLR  0.694475  0.041907
# 1   Mendelian traits    all       GPN-MSA      abs(LLR)  0.654223  0.044973
# 2   Mendelian traits    all       GPN-MSA      L2 dist.  0.206924  0.020884
# 3   Mendelian traits    all       GPN-MSA  Cosine dist.  0.208002  0.020988
# 4   Mendelian traits    all       GPN-MSA   Inner prod.  0.301125  0.031690
# 5   Mendelian traits    all  gLM-Promoter           LLR  0.421676  0.069664
# 6   Mendelian traits    all  gLM-Promoter      abs(LLR)  0.378816  0.068633
# 7   Mendelian traits    all  gLM-Promoter      L2 dist.  0.344996  0.056300
# 8   Mendelian traits    all  gLM-Promoter  Cosine dist.  0.263391  0.038219
# 9   Mendelian traits    all  gLM-Promoter   Inner prod.  0.169318  0.047518
# 10  Mendelian traits    all            NT           LLR  0.119961  0.005964
# 11  Mendelian traits    all            NT      abs(LLR)  0.098064  0.006411
# 12  Mendelian traits    all            NT      L2 dist.  0.187644  0.022908
# 13  Mendelian traits    all            NT  Cosine dist.  0.185598  0.022145
# 14  Mendelian traits    all            NT   Inner prod.  0.184916  0.038922
# 15  Mendelian traits    all      HyenaDNA           LLR  0.115205  0.006084
# 16  Mendelian traits    all      HyenaDNA      abs(LLR)  0.106483  0.005712
# 17  Mendelian traits    all      HyenaDNA      L2 dist.  0.116893  0.014477
# 18  Mendelian traits    all      HyenaDNA  Cosine dist.  0.116403  0.013541
# 19  Mendelian traits    all      HyenaDNA   Inner prod.  0.164817  0.031015
# 20  Mendelian traits    all      Caduceus           LLR  0.107708  0.005421
# 21  Mendelian traits    all      Caduceus      abs(LLR)  0.087799  0.005566
# 22  Mendelian traits    all      Caduceus      L2 dist.  0.134898  0.009045
# 23  Mendelian traits    all      Caduceus  Cosine dist.  0.134559  0.010093
# 24  Mendelian traits    all      Caduceus   Inner prod.  0.131076  0.016255
# 25    Complex traits    all       GPN-MSA           LLR  0.212286  0.009691
# 26    Complex traits    all       GPN-MSA      abs(LLR)  0.223643  0.009396
# 27    Complex traits    all       GPN-MSA      L2 dist.  0.150157  0.006486
# 28    Complex traits    all       GPN-MSA  Cosine dist.  0.150226  0.006510
# 29    Complex traits    all       GPN-MSA   Inner prod.  0.176527  0.009632
# 30    Complex traits    all  gLM-Promoter           LLR  0.112302  0.003315
# 31    Complex traits    all  gLM-Promoter      abs(LLR)  0.109684  0.004063
# 32    Complex traits    all  gLM-Promoter      L2 dist.  0.126253  0.004143
# 33    Complex traits    all  gLM-Promoter  Cosine dist.  0.126480  0.003299
# 34    Complex traits    all  gLM-Promoter   Inner prod.  0.124610  0.004276
# 35    Complex traits    all            NT           LLR  0.100768  0.002226
# 36    Complex traits    all            NT      abs(LLR)  0.099983  0.002484
# 37    Complex traits    all            NT      L2 dist.  0.117851  0.004587
# 38    Complex traits    all            NT  Cosine dist.  0.119393  0.004889
# 39    Complex traits    all            NT   Inner prod.  0.135522  0.005529
# 40    Complex traits    all      HyenaDNA           LLR  0.109734  0.003578
# 41    Complex traits    all      HyenaDNA      abs(LLR)  0.110800  0.003108
# 42    Complex traits    all      HyenaDNA      L2 dist.  0.102096  0.004941
# 43    Complex traits    all      HyenaDNA  Cosine dist.  0.101709  0.004492
# 44    Complex traits    all      HyenaDNA   Inner prod.  0.117746  0.003630
# 45    Complex traits    all      Caduceus           LLR  0.098274  0.001875
# 46    Complex traits    all      Caduceus      abs(LLR)  0.097118  0.001969
# 47    Complex traits    all      Caduceus      L2 dist.  0.114716  0.003663
# 48    Complex traits    all      Caduceus  Cosine dist.  0.115082  0.003761
# 49    Complex traits    all      Caduceus   Inner prod.  0.116676  0.006249
#
#     value
# 0   0.694
# 1   0.654
# 2   0.207
# 3   0.208
# 4   0.301
# 5   0.422
# 6   0.379
# 7   0.345
# 8   0.263
# 9   0.169
# 10  0.120
# 11  0.098
# 12  0.188
# 13  0.186
# 14  0.185
# 15  0.115
# 16  0.106
# 17  0.117
# 18  0.116
# 19  0.165
# 20  0.108
# 21  0.088
# 22  0.135
# 23  0.135
# 24  0.131
# 25  0.212
# 26  0.224
# 27  0.150
# 28  0.150
# 29  0.177
# 30  0.112
# 31  0.110
# 32  0.126
# 33  0.126
# 34  0.125
# 35  0.101
# 36  0.100
# 37  0.118
# 38  0.119
# 39  0.136
# 40  0.110
# 41  0.111
# 42  0.102
# 43  0.102
# 44  0.118
# 45  0.098
# 46  0.097
# 47  0.115
# 48  0.115
# 49  0.117

# %%
df = df.pivot_table(
    columns=[
        "score",
    ],
    index=[
        "dataset",
        #"subset",
        "model",
    ],
    values="value",
    aggfunc="first", sort=False,
)
df
# Out:
# score                            LLR abs(LLR) L2 dist. Cosine dist.  \
# dataset          model
# Mendelian traits GPN-MSA       0.694    0.654    0.207        0.208
#                  gLM-Promoter  0.422    0.379    0.345        0.263
#                  NT            0.120    0.098    0.188        0.186
#                  HyenaDNA      0.115    0.106    0.117        0.116
#                  Caduceus      0.108    0.088    0.135        0.135
# Complex traits   GPN-MSA       0.212    0.224    0.150        0.150
#                  gLM-Promoter  0.112    0.110    0.126        0.126
#                  NT            0.101    0.100    0.118        0.119
#                  HyenaDNA      0.110    0.111    0.102        0.102
#                  Caduceus      0.098    0.097    0.115        0.115
#
# score                         Inner prod.
# dataset          model
# Mendelian traits GPN-MSA            0.301
#                  gLM-Promoter       0.169
#                  NT                 0.185
#                  HyenaDNA           0.165
#                  Caduceus           0.131
# Complex traits   GPN-MSA            0.177
#                  gLM-Promoter       0.125
#                  NT                 0.136
#                  HyenaDNA           0.118
#                  Caduceus           0.117

# %%
def boldface_best_model(x):
    threshold = 0.01
    y = x.astype(float)
    best_score = y.max()
    best_models = y[(best_score - y) < threshold].index
    res = x.copy()
    for best_model in best_models:
        res[best_model] = r"\textbf{" + res[best_model] + r"}"
    return res

df = df.apply(boldface_best_model, axis=1)
df
# Out:
# score                                     LLR        abs(LLR)        L2 dist.  \
# dataset          model
# Mendelian traits GPN-MSA       \textbf{0.694}           0.654           0.207
#                  gLM-Promoter  \textbf{0.422}           0.379           0.345
#                  NT                     0.120           0.098  \textbf{0.188}
#                  HyenaDNA               0.115           0.106           0.117
#                  Caduceus               0.108           0.088  \textbf{0.135}
# Complex traits   GPN-MSA                0.212  \textbf{0.224}           0.150
#                  gLM-Promoter           0.112           0.110  \textbf{0.126}
#                  NT                     0.101           0.100           0.118
#                  HyenaDNA      \textbf{0.110}  \textbf{0.111}           0.102
#                  Caduceus               0.098           0.097  \textbf{0.115}
#
# score                            Cosine dist.     Inner prod.
# dataset          model
# Mendelian traits GPN-MSA                0.208           0.301
#                  gLM-Promoter           0.263           0.169
#                  NT            \textbf{0.186}  \textbf{0.185}
#                  HyenaDNA               0.116  \textbf{0.165}
#                  Caduceus      \textbf{0.135}  \textbf{0.131}
# Complex traits   GPN-MSA                0.150           0.177
#                  gLM-Promoter  \textbf{0.126}  \textbf{0.125}
#                  NT                     0.119  \textbf{0.136}
#                  HyenaDNA               0.102  \textbf{0.118}
#                  Caduceus      \textbf{0.115}  \textbf{0.117}

# %%
#df.index.names = [None, None]
df.index.name = None
#df.columns.names = [None, None]
df.columns.name = None

# %%
print(df.to_latex(multicolumn_format='c', escape=False))
# Out:
# \begin{tabular}{lllllll}
# \toprule
#  &  & LLR & abs(LLR) & L2 dist. & Cosine dist. & Inner prod. \\
# dataset & model &  &  &  &  &  \\
# \midrule
# \multirow[t]{5}{*}{Mendelian traits} & GPN-MSA & \textbf{0.694} & 0.654 & 0.207 & 0.208 & 0.301 \\
#  & gLM-Promoter & \textbf{0.422} & 0.379 & 0.345 & 0.263 & 0.169 \\
#  & NT & 0.120 & 0.098 & \textbf{0.188} & \textbf{0.186} & \textbf{0.185} \\
#  & HyenaDNA & 0.115 & 0.106 & 0.117 & 0.116 & \textbf{0.165} \\
#  & Caduceus & 0.108 & 0.088 & \textbf{0.135} & \textbf{0.135} & \textbf{0.131} \\
# \cline{1-7}
# \multirow[t]{5}{*}{Complex traits} & GPN-MSA & 0.212 & \textbf{0.224} & 0.150 & 0.150 & 0.177 \\
#  & gLM-Promoter & 0.112 & 0.110 & \textbf{0.126} & \textbf{0.126} & \textbf{0.125} \\
#  & NT & 0.101 & 0.100 & 0.118 & 0.119 & \textbf{0.136} \\
#  & HyenaDNA & \textbf{0.110} & \textbf{0.111} & 0.102 & 0.102 & \textbf{0.118} \\
#  & Caduceus & 0.098 & 0.097 & \textbf{0.115} & \textbf{0.115} & \textbf{0.117} \\
# \cline{1-7}
# \bottomrule
# \end{tabular}
