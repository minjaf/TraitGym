# %%
import pandas as pd
import polars as pl
from tqdm import tqdm

# %%
NON_EXONIC = [
    "intergenic_variant",
    "intron_variant",
    "upstream_gene_variant",
    "downstream_gene_variant"
]

cre_classes = ["PLS", "pELS", "dELS", "DNase-H3K4me3", "CTCF-only"]
cre_flank_classes = [f"{c}_flank" for c in cre_classes]

# %%
traits = pd.read_csv(
    "../../results/gwas_gokcen/raw/disease_list.txt", delim_whitespace=True, header=None,
    names=["trait", "source", "name"]
).trait.unique()
traits
# Out:
# array(['AD', 'ADHD', 'AIT', 'ASM', 'BMD-HT', 'BMI', 'BP', 'Breast_cancer',
#        'CAD', 'CD', 'Celiac', 'CVD', 'ECOL', 'Eczema', 'EY', 'FG',
#        'Glucose', 'HbA1c', 'HDL', 'Height', 'HT', 'HTN', 'IBD',
#        'Insomnia', 'Intel', 'LDL', 'MCH', 'MDD', 'MNP', 'MNR', 'MS',
#        'NRT', 'PLT', 'RA', 'RBC', 'RDW', 'RR-ENT', 'SCZ', 'SLE', 'SWB',
#        'T2D', 'TC', 'TG', 'WHR'], dtype=object)

# %%
V_cre = pl.read_parquet("../../results/gwas_gokcen/coords.annot_with_cre.parquet")
V_cre = V_cre.filter(V_cre["consequence"].is_in(NON_EXONIC + cre_classes + cre_flank_classes))
V_cre
# Out:
# shape: (757_583, 5)
# ┌───────┬──────────┬─────┬─────┬─────────────────┐
# │ chrom ┆ pos      ┆ ref ┆ alt ┆ consequence     │
# │ ---   ┆ ---      ┆ --- ┆ --- ┆ ---             │
# │ str   ┆ i64      ┆ str ┆ str ┆ str             │
# ╞═══════╪══════════╪═════╪═════╪═════════════════╡
# │ 1     ┆ 950296   ┆ C   ┆ A   ┆ intron_variant  │
# │ 1     ┆ 951408   ┆ G   ┆ A   ┆ CTCF-only_flank │
# │ 1     ┆ 952180   ┆ A   ┆ C   ┆ CTCF-only_flank │
# │ 1     ┆ 955679   ┆ C   ┆ T   ┆ dELS            │
# │ 1     ┆ 956565   ┆ A   ┆ G   ┆ intron_variant  │
# │ …     ┆ …        ┆ …   ┆ …   ┆ …               │
# │ 22    ┆ 50712045 ┆ G   ┆ A   ┆ intron_variant  │
# │ 22    ┆ 50712922 ┆ C   ┆ T   ┆ intron_variant  │
# │ 22    ┆ 50713203 ┆ C   ┆ T   ┆ dELS_flank      │
# │ 22    ┆ 50713214 ┆ C   ┆ T   ┆ dELS_flank      │
# │ 22    ┆ 50713296 ┆ C   ┆ T   ┆ dELS_flank      │
# └───────┴──────────┴─────┴─────┴─────────────────┘

# %%
res = []
for trait in tqdm(traits):
    V = pl.read_parquet(f"../../results/gwas_gokcen/processed/{trait}.parquet")
    res.append([trait, (V["PIP"] > 0.9).sum(), (V["PIP"] < 0.01).sum()])
res = pd.DataFrame(res, columns=["trait", "n_pos", "n_neg"])
res = res.sort_values("n_pos", ascending=False)
res
# Out:
# 100%|████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 104.98it/s]
#             trait  n_pos   n_neg
# 19         Height    571  258346
# 4          BMD-HT    258  107833
# 32            PLT    252  110446
# 26            MCH    240   85326
# 18            HDL    198   50863
# 34            RBC    196   71452
# 35            RDW    189   67325
# 42             TG    146   45949
# 22            IBD    125    1530
# 17          HbA1c    113   37285
# 5             BMI     99   60773
# 41             TC     91   30288
# 9              CD     88    1415
# 43            WHR     81   36588
# 25            LDL     79   23822
# 21            HTN     61   27726
# 29            MNR     46   26309
# 11            CVD     46   13436
# 16        Glucose     36    8400
# 13         Eczema     34   12517
# 8             CAD     26    5537
# 3             ASM     25    8575
# 20             HT     23    7340
# 12           ECOL     21   17728
# 40            T2D     20    3702
# 14             EY     20   15928
# 28            MNP     18    6188
# 24          Intel     18    9703
# 36         RR-ENT     18    7034
# 15             FG     14      57
# 30             MS     12    3013
# 7   Breast_cancer     12    3531
# 0              AD     11    1379
# 2             AIT      9    3443
# 38            SLE      7    1747
# 37            SCZ      6    8865
# 39            SWB      5   10194
# 31            NRT      4    6872
# 27            MDD      4    3489
# 6              BP      2     126
# 33             RA      2      35
# 23       Insomnia      0     358
# 1            ADHD      0     191
# 10         Celiac      0    4273

# %%
res = []
for trait in tqdm(traits):
    V = pl.read_parquet(f"../../results/gwas_gokcen/processed/{trait}.parquet")
    V = V.join(V_cre, on=["chrom", "pos", "ref", "alt"], how="inner")
    res.append([trait, (V["PIP"] > 0.9).sum(), (V["PIP"] < 0.01).sum()])
res = pd.DataFrame(res, columns=["trait", "n_pos", "n_neg"])
res = res.sort_values("n_pos", ascending=False)
res
# Out:
# 100%|█████████████████████████████████████████████████████████| 44/44 [00:00<00:00, 54.90it/s]
#             trait  n_pos   n_neg
# 19         Height    372  240293
# 4          BMD-HT    195  101474
# 32            PLT    187  100804
# 26            MCH    170   78005
# 18            HDL    161   46626
# 35            RDW    128   61335
# 34            RBC    128   65382
# 42             TG    119   42399
# 22            IBD    112    1327
# 9              CD     83    1249
# 17          HbA1c     80   34156
# 41             TC     70   27609
# 43            WHR     57   34117
# 5             BMI     57   57741
# 25            LDL     55   21727
# 21            HTN     41   25988
# 16        Glucose     33    7776
# 29            MNR     29   24985
# 13         Eczema     26   11614
# 11            CVD     25   12477
# 40            T2D     18    3503
# 12           ECOL     17   16554
# 20             HT     17    6794
# 14             EY     17   14857
# 8             CAD     15    5103
# 3             ASM     15    7968
# 28            MNP     13    5596
# 15             FG     13      53
# 0              AD     10    1268
# 36         RR-ENT      9    6490
# 30             MS      9    2759
# 7   Breast_cancer      9    3388
# 24          Intel      9    9105
# 2             AIT      7    3200
# 39            SWB      4    9661
# 37            SCZ      4    8249
# 27            MDD      3    3305
# 6              BP      2     113
# 38            SLE      2    1577
# 33             RA      2      31
# 31            NRT      2    6369
# 10         Celiac      0    3914
# 23       Insomnia      0     342
# 1            ADHD      0     182

# %%
df = pl.read_csv("../../results/gwas_gokcen/raw/IBD-deLange2017.susie.gwfinemap.b38.gz", separator="\t")
df
# Out:
# shape: (6_073_445, 14)
# ┌───────┬─────────────┬──────────┬─────┬───┬──────────┬──────────────┬────────────┬──────────────┐
# │ CHR   ┆ SNP         ┆ BP       ┆ A1  ┆ … ┆ PIP      ┆ BETA_MEAN    ┆ BETA_SD    ┆ CREDIBLE_SET │
# │ ---   ┆ ---         ┆ ---      ┆ --- ┆   ┆ ---      ┆ ---          ┆ ---        ┆ ---          │
# │ str   ┆ str         ┆ i64      ┆ str ┆   ┆ f64      ┆ f64          ┆ f64        ┆ i64          │
# ╞═══════╪═════════════╪══════════╪═════╪═══╪══════════╪══════════════╪════════════╪══════════════╡
# │ chr1  ┆ rs61769339  ┆ 727242   ┆ G   ┆ … ┆ 0.0      ┆ 6.2064e-179  ┆ 8.1394e-91 ┆ 0            │
# │ chr1  ┆ rs12238997  ┆ 758351   ┆ A   ┆ … ┆ 0.0      ┆ -6.7713e-181 ┆ 9.2966e-92 ┆ 0            │
# │ chr1  ┆ rs189800799 ┆ 766455   ┆ T   ┆ … ┆ 0.0      ┆ -1.3112e-179 ┆ 3.4150e-91 ┆ 0            │
# │ chr1  ┆ rs114983708 ┆ 778639   ┆ A   ┆ … ┆ 0.0      ┆ -3.6255e-179 ┆ 6.0389e-91 ┆ 0            │
# │ chr1  ┆ rs138660747 ┆ 778897   ┆ C   ┆ … ┆ 0.0      ┆ 1.0589e-180  ┆ 9.3934e-92 ┆ 0            │
# │ …     ┆ …           ┆ …        ┆ …   ┆ … ┆ …        ┆ …            ┆ …          ┆ …            │
# │ chr22 ┆ rs189416433 ┆ 50788192 ┆ T   ┆ … ┆ 0.000425 ┆ 1.4565e-7    ┆ 0.0000746  ┆ 0            │
# │ chr22 ┆ rs9616985   ┆ 50791377 ┆ T   ┆ … ┆ 0.000451 ┆ -5.7109e-7   ┆ 0.000081   ┆ 0            │
# │ chr22 ┆ rs144549712 ┆ 50791427 ┆ G   ┆ … ┆ 0.000516 ┆ -0.000001    ┆ 0.000097   ┆ 0            │
# │ chr22 ┆ rs191117135 ┆ 50796371 ┆ G   ┆ … ┆ 0.00537  ┆ -0.000044    ┆ 0.000651   ┆ 0            │
# │ chr22 ┆ rs3896457   ┆ 50798635 ┆ T   ┆ … ┆ 0.000423 ┆ 1.7517e-8    ┆ 0.000074   ┆ 0            │
# └───────┴─────────────┴──────────┴─────┴───┴──────────┴──────────────┴────────────┴──────────────┘

# %%
df = df.filter(pl.col("PIP") > 0.9)
df
# Out:
# shape: (1_104, 14)
# ┌───────┬─────────────┬──────────┬─────┬───┬──────────┬───────────┬──────────┬──────────────┐
# │ CHR   ┆ SNP         ┆ BP       ┆ A1  ┆ … ┆ PIP      ┆ BETA_MEAN ┆ BETA_SD  ┆ CREDIBLE_SET │
# │ ---   ┆ ---         ┆ ---      ┆ --- ┆   ┆ ---      ┆ ---       ┆ ---      ┆ ---          │
# │ str   ┆ str         ┆ i64      ┆ str ┆   ┆ f64      ┆ f64       ┆ f64      ┆ i64          │
# ╞═══════╪═════════════╪══════════╪═════╪═══╪══════════╪═══════════╪══════════╪══════════════╡
# │ chr1  ┆ rs2275916   ┆ 1439425  ┆ G   ┆ … ┆ 1.0      ┆ -0.270234 ┆ 0.003744 ┆ 9            │
# │ chr1  ┆ rs1892289   ┆ 1439454  ┆ A   ┆ … ┆ 1.0      ┆ 1.22924   ┆ 0.003744 ┆ 6            │
# │ chr1  ┆ rs4590      ┆ 1440430  ┆ C   ┆ … ┆ 1.0      ┆ 1.06555   ┆ 0.003744 ┆ 4            │
# │ chr1  ┆ rs711180    ┆ 1442793  ┆ G   ┆ … ┆ 1.0      ┆ -2.0247   ┆ 0.003744 ┆ 5            │
# │ chr1  ┆ rs147959152 ┆ 1443620  ┆ G   ┆ … ┆ 1.0      ┆ -1.06692  ┆ 0.003744 ┆ 3            │
# │ …     ┆ …           ┆ …        ┆ …   ┆ … ┆ …        ┆ …         ┆ …        ┆ …            │
# │ chr22 ┆ rs9611176   ┆ 39441998 ┆ A   ┆ … ┆ 1.0      ┆ 0.269764  ┆ 0.004086 ┆ 9            │
# │ chr22 ┆ rs113200473 ┆ 39457735 ┆ G   ┆ … ┆ 1.0      ┆ -0.493977 ┆ 0.004083 ┆ 7            │
# │ chr22 ┆ rs7286917   ┆ 39464863 ┆ A   ┆ … ┆ 1.0      ┆ 0.234959  ┆ 0.004083 ┆ 2            │
# │ chr22 ┆ rs151114897 ┆ 39497671 ┆ C   ┆ … ┆ 0.999537 ┆ -0.087313 ┆ 0.00449  ┆ 8            │
# │ chr22 ┆ rs28634677  ┆ 49957690 ┆ C   ┆ … ┆ 0.999554 ┆ -0.027344 ┆ 0.004163 ┆ 1            │
# └───────┴─────────────┴──────────┴─────┴───┴──────────┴───────────┴──────────┴──────────────┘

# %%
df.filter(pl.col("P") < 5e-8)
# Out:
# shape: (125, 14)
# ┌───────┬────────────┬──────────┬─────┬───┬──────────┬───────────┬───────────┬──────────────┐
# │ CHR   ┆ SNP        ┆ BP       ┆ A1  ┆ … ┆ PIP      ┆ BETA_MEAN ┆ BETA_SD   ┆ CREDIBLE_SET │
# │ ---   ┆ ---        ┆ ---      ┆ --- ┆   ┆ ---      ┆ ---       ┆ ---       ┆ ---          │
# │ str   ┆ str        ┆ i64      ┆ str ┆   ┆ f64      ┆ f64       ┆ f64       ┆ i64          │
# ╞═══════╪════════════╪══════════╪═════╪═══╪══════════╪═══════════╪═══════════╪══════════════╡
# │ chr1  ┆ rs59523164 ┆ 7911767  ┆ G   ┆ … ┆ 1.0      ┆ 0.189047  ┆ 0.005769  ┆ 3            │
# │ chr1  ┆ rs2641116  ┆ 7969434  ┆ T   ┆ … ┆ 0.921796 ┆ -0.097197 ┆ 0.0394404 ┆ 6            │
# │ chr1  ┆ rs1883679  ┆ 8040391  ┆ T   ┆ … ┆ 1.0      ┆ -0.211305 ┆ 0.006536  ┆ 2            │
# │ chr1  ┆ rs34045935 ┆ 8126172  ┆ C   ┆ … ┆ 1.0      ┆ 0.230465  ┆ 0.005774  ┆ 1            │
# │ chr1  ┆ rs72635736 ┆ 8229192  ┆ T   ┆ … ┆ 1.0      ┆ -0.092932 ┆ 0.00408   ┆ 4            │
# │ …     ┆ …          ┆ …        ┆ …   ┆ … ┆ …        ┆ …         ┆ …         ┆ …            │
# │ chr21 ┆ rs1736161  ┆ 15460903 ┆ G   ┆ … ┆ 0.909562 ┆ 0.137112  ┆ 0.0592834 ┆ 8            │
# │ chr21 ┆ rs2876932  ┆ 44198653 ┆ A   ┆ … ┆ 1.0      ┆ -0.090716 ┆ 0.004122  ┆ 1            │
# │ chr22 ┆ rs5754467  ┆ 21630805 ┆ A   ┆ … ┆ 1.0      ┆ 0.0893791 ┆ 0.004118  ┆ 1            │
# │ chr22 ┆ rs714027   ┆ 30181782 ┆ A   ┆ … ┆ 1.0      ┆ -0.059962 ┆ 0.004113  ┆ 2            │
# │ chr22 ┆ rs17304621 ┆ 39294786 ┆ C   ┆ … ┆ 0.984262 ┆ 0.0476312 ┆ 0.007251  ┆ 1            │
# └───────┴────────────┴──────────┴─────┴───┴──────────┴───────────┴───────────┴──────────────┘

# %%
df.filter(pl.col("P") < 0.05)
# Out:
# shape: (808, 14)
# ┌───────┬─────────────┬──────────┬─────┬───┬──────────┬───────────┬───────────┬──────────────┐
# │ CHR   ┆ SNP         ┆ BP       ┆ A1  ┆ … ┆ PIP      ┆ BETA_MEAN ┆ BETA_SD   ┆ CREDIBLE_SET │
# │ ---   ┆ ---         ┆ ---      ┆ --- ┆   ┆ ---      ┆ ---       ┆ ---       ┆ ---          │
# │ str   ┆ str         ┆ i64      ┆ str ┆   ┆ f64      ┆ f64       ┆ f64       ┆ i64          │
# ╞═══════╪═════════════╪══════════╪═════╪═══╪══════════╪═══════════╪═══════════╪══════════════╡
# │ chr1  ┆ rs2275916   ┆ 1439425  ┆ G   ┆ … ┆ 1.0      ┆ -0.270234 ┆ 0.003744  ┆ 9            │
# │ chr1  ┆ rs1892289   ┆ 1439454  ┆ A   ┆ … ┆ 1.0      ┆ 1.22924   ┆ 0.003744  ┆ 6            │
# │ chr1  ┆ rs4590      ┆ 1440430  ┆ C   ┆ … ┆ 1.0      ┆ 1.06555   ┆ 0.003744  ┆ 4            │
# │ chr1  ┆ rs711180    ┆ 1442793  ┆ G   ┆ … ┆ 1.0      ┆ -2.0247   ┆ 0.003744  ┆ 5            │
# │ chr1  ┆ rs34388881  ┆ 1446303  ┆ G   ┆ … ┆ 1.0      ┆ -0.61367  ┆ 0.003744  ┆ 1            │
# │ …     ┆ …           ┆ …        ┆ …   ┆ … ┆ …        ┆ …         ┆ …         ┆ …            │
# │ chr22 ┆ rs149953174 ┆ 39329225 ┆ G   ┆ … ┆ 1.0      ┆ 0.121061  ┆ 0.004081  ┆ 5            │
# │ chr22 ┆ rs5750808   ┆ 39394982 ┆ G   ┆ … ┆ 0.986959 ┆ -0.471763 ┆ 0.0543812 ┆ 3            │
# │ chr22 ┆ rs7288760   ┆ 39423964 ┆ A   ┆ … ┆ 1.0      ┆ 0.479741  ┆ 0.004083  ┆ 6            │
# │ chr22 ┆ rs9611176   ┆ 39441998 ┆ A   ┆ … ┆ 1.0      ┆ 0.269764  ┆ 0.004086  ┆ 9            │
# │ chr22 ┆ rs151114897 ┆ 39497671 ┆ C   ┆ … ┆ 0.999537 ┆ -0.087313 ┆ 0.00449   ┆ 8            │
# └───────┴─────────────┴──────────┴─────┴───┴──────────┴───────────┴───────────┴──────────────┘
