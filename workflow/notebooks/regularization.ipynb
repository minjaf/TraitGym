# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import polars as pl
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression, Ridge
from sklearn.metrics import average_precision_score, roc_auc_score
from sklearn.model_selection import GroupKFold, GridSearchCV
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.pipeline import Pipeline
from tqdm import tqdm

# %%
dataset = "omim_matched_9"
base_dir = f"../../results/dataset/{dataset}"
V = pd.read_parquet(f"{base_dir}/test.parquet")
V
# Out:
#      chrom        pos ref alt  OMIM            consequence  label  tss_dist  \
# 0        1    1425822   C   G  None                    PLS  False        48
# 1        1    1615869   C   T  None                    PLS  False        35
# 2        1    1659060   G   A  None                    PLS  False        47
# 3        1    2050958   T   C  None    5_prime_UTR_variant  False       149
# 4        1    2074688   G   A  None    5_prime_UTR_variant  False         0
# ...    ...        ...  ..  ..   ...                    ...    ...       ...
# 3865     X  155613005   C   T  None                    PLS  False        52
# 3866     X  155719093   C   A  None    5_prime_UTR_variant  False         4
# 3867     X  155881342   A   C  None                    PLS  False         2
# 3868     X  155881414   C   T  None    5_prime_UTR_variant  False        35
# 3869     X  156020793   A   G  None  upstream_gene_variant  False       167
#
#                   match_group
# 0                       PLS_4
# 1                       PLS_0
# 2                       PLS_4
# 3       5_prime_UTR_variant_7
# 4       5_prime_UTR_variant_2
# ...                       ...
# 3865                   PLS_62
# 3866  5_prime_UTR_variant_105
# 3867                   PLS_68
# 3868  5_prime_UTR_variant_115
# 3869  upstream_gene_variant_9
#
# [3870 rows x 9 columns]

# %%
feature_names = [
    "GPN-MSA_LLR",
    "GPN-MSA_InnerProducts",
]

all_features = []
for features in feature_names:
    df = pd.read_parquet(f"{base_dir}/features/{features}.parquet")
    df.columns = [f"{features}_{col}" for col in df.columns]
    all_features += df.columns.tolist()
    V = pd.concat([V, df], axis=1)
V
# Out:
#      chrom        pos ref alt  OMIM            consequence  label  tss_dist  \
# 0        1    1425822   C   G  None                    PLS  False        48
# 1        1    1615869   C   T  None                    PLS  False        35
# 2        1    1659060   G   A  None                    PLS  False        47
# 3        1    2050958   T   C  None    5_prime_UTR_variant  False       149
# 4        1    2074688   G   A  None    5_prime_UTR_variant  False         0
# ...    ...        ...  ..  ..   ...                    ...    ...       ...
# 3865     X  155613005   C   T  None                    PLS  False        52
# 3866     X  155719093   C   A  None    5_prime_UTR_variant  False         4
# 3867     X  155881342   A   C  None                    PLS  False         2
# 3868     X  155881414   C   T  None    5_prime_UTR_variant  False        35
# 3869     X  156020793   A   G  None  upstream_gene_variant  False       167
#
#                   match_group  GPN-MSA_LLR_score  ...  \
# 0                       PLS_4           3.439453  ...
# 1                       PLS_0           0.529785  ...
# 2                       PLS_4          -0.802246  ...
# 3       5_prime_UTR_variant_7           1.386719  ...
# 4       5_prime_UTR_variant_2           0.347168  ...
# ...                       ...                ...  ...
# 3865                   PLS_62           1.066406  ...
# 3866  5_prime_UTR_variant_105           0.505859  ...
# 3867                   PLS_68          -3.859375  ...
# 3868  5_prime_UTR_variant_115          -1.322266  ...
# 3869  upstream_gene_variant_9          -2.289062  ...
#
#       GPN-MSA_InnerProducts_embedding_758  \
# 0                              128.732819
# 1                              147.545822
# 2                               88.503456
# 3                               92.255478
# 4                               62.511314
# ...                                   ...
# 3865                            83.412796
# 3866                           107.956505
# 3867                            81.035919
# 3868                            59.554832
# 3869                           149.693024
#
#       GPN-MSA_InnerProducts_embedding_759  \
# 0                              159.598480
# 1                              171.706024
# 2                              236.405533
# 3                              253.419617
# 4                              223.224915
# ...                                   ...
# 3865                           218.358795
# 3866                           508.437225
# 3867                           113.946785
# 3868                           183.954376
# 3869                           184.636200
#
#       GPN-MSA_InnerProducts_embedding_760  \
# 0                               74.421951
# 1                               46.736801
# 2                               35.817936
# 3                               60.395531
# 4                               85.186905
# ...                                   ...
# 3865                            57.655621
# 3866                            47.225998
# 3867                            69.781052
# 3868                            78.128311
# 3869                            47.619179
#
#       GPN-MSA_InnerProducts_embedding_761  \
# 0                               73.623795
# 1                               43.170914
# 2                               73.384224
# 3                               50.736336
# 4                               95.258102
# ...                                   ...
# 3865                            71.613922
# 3866                           240.112335
# 3867                            73.995590
# 3868                            61.767647
# 3869                            98.688705
#
#       GPN-MSA_InnerProducts_embedding_762  \
# 0                               38.545086
# 1                               42.430355
# 2                               48.623886
# 3                               29.582539
# 4                               47.534737
# ...                                   ...
# 3865                            37.866199
# 3866                           107.949043
# 3867                            53.434326
# 3868                            42.667374
# 3869                            41.006119
#
#       GPN-MSA_InnerProducts_embedding_763  \
# 0                               73.916550
# 1                               54.364761
# 2                               55.552979
# 3                               90.220230
# 4                               63.498165
# ...                                   ...
# 3865                            70.055969
# 3866                           108.419098
# 3867                            80.101067
# 3868                            56.545998
# 3869                            58.938316
#
#       GPN-MSA_InnerProducts_embedding_764  \
# 0                              142.523422
# 1                              158.388382
# 2                               62.625595
# 3                               90.312042
# 4                               70.662926
# ...                                   ...
# 3865                           123.362350
# 3866                           195.913254
# 3867                           151.518570
# 3868                           114.332726
# 3869                            95.098244
#
#       GPN-MSA_InnerProducts_embedding_765  \
# 0                              145.709167
# 1                               71.366440
# 2                               68.485321
# 3                               96.651627
# 4                              192.659454
# ...                                   ...
# 3865                            97.474365
# 3866                           287.693695
# 3867                            93.543678
# 3868                           124.544868
# 3869                           179.273193
#
#       GPN-MSA_InnerProducts_embedding_766  GPN-MSA_InnerProducts_embedding_767
# 0                               58.040916                           158.960846
# 1                               41.952412                           157.829102
# 2                               53.198612                           119.029610
# 3                               31.374359                           154.576050
# 4                               33.813946                           167.253983
# ...                                   ...                                  ...
# 3865                            58.502895                           160.284714
# 3866                           270.265503                            65.540878
# 3867                            81.852676                           143.471146
# 3868                            47.406349                           160.134476
# 3869                            47.383705                           106.864334
#
# [3870 rows x 778 columns]

# %%
V["train_mask"] = V.chrom.isin([str(i) for i in range(1, 23, 2)] + ["X"])
V_train = V[V.train_mask]
V_test = V[~V.train_mask]
len(V_train), len(V_test)
# Out:
# (2900, 970)

# %%
X_train = V_train[all_features]
y_train = V_train["label"]
X_test = V_test[all_features]
y_test = V_test["label"]

# %%
clf = Pipeline([
    ('imputer', SimpleImputer(
        missing_values=np.nan, strategy='mean', keep_empty_features=True,
    )),
    ('scaler', StandardScaler()),
    ('linear', LogisticRegression(
        class_weight="balanced",
        random_state=42,
        #penalty="elasticnet",
        #l1_ratio=0.5,
        penalty="l1",
        solver="saga",
        #C=1e-3,
        C=2.7e-3,
        #C=1,
        n_jobs=-1,
    ))
])
clf.fit(X_train, y_train)
linear = clf.named_steps["linear"]
coef = pd.DataFrame({
    "feature": X_train.columns,
    "coef": linear.coef_[0],
}).sort_values("coef", ascending=False, key=abs)
print(coef.head(10))
print(f"{(coef.coef != 0).sum()=}")
# Out:
#                                  feature      coef
# 6      GPN-MSA_InnerProducts_embedding_5  0.024365
# 0                      GPN-MSA_LLR_score  0.000000
# 517  GPN-MSA_InnerProducts_embedding_516  0.000000
# 507  GPN-MSA_InnerProducts_embedding_506  0.000000
# 508  GPN-MSA_InnerProducts_embedding_507  0.000000
# 509  GPN-MSA_InnerProducts_embedding_508  0.000000
# 510  GPN-MSA_InnerProducts_embedding_509  0.000000
# 511  GPN-MSA_InnerProducts_embedding_510  0.000000
# 512  GPN-MSA_InnerProducts_embedding_511  0.000000
# 513  GPN-MSA_InnerProducts_embedding_512  0.000000
# (coef.coef != 0).sum()=1

# %%
# train on odd
# C, n_selected, AUPRC
# 1e-3, 1, 0.541
# 1, 713, 0.645

# train on even
# 1, 561, 0.53
average_precision_score(y_test, clf.predict_proba(X_test)[:, 1])
# Out:
# 0.39916359390050987

# %%
average_precision_score(y_test, -V_test["GPN-MSA_LLR_score"])
# Out:
# 0.6917278715099429
