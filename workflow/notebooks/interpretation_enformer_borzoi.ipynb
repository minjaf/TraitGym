# %%
import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
def format_number(num):
    """
    Converts a number into a more readable format, using K for thousands, M for millions, etc.
    Args:
    - num: The number to format.
    
    Returns:
    - A formatted string representing the number.
    """
    if num >= 1e9:
        return f'{num/1e9:.1f}B'
    elif num >= 1e6:
        return f'{num/1e6:.1f}M'
    elif num >= 1e3:
        return f'{num/1e3:.1f}K'
    else:
        return str(num)

def make_plots():
    metric = df.columns[0]
    
    for subset in subsets:
        n_pos, n_neg = sample_size[subset]
        if metric == "AUROC":
            baseline = 0.5
        elif metric == "AUPRC":
            baseline = n_pos / (n_pos + n_neg)
        elif metric == "Odds ratio":
            baseline = 1
        g = sns.catplot(
            data=df[df.subset==subset],
            y="feature",
            x=metric,
            row="Model",
            sharex=True,
            sharey=False,
            kind="bar",
            color="C0",
            height=3,
            aspect=2,
        )
        g.set(
            xlim=baseline,
            ylabel="",
        )
        g.set_titles("{row_name}")
        sample_size_str = f"n={format_number(n_pos)} vs. {format_number(n_neg)}"
        plt.suptitle(
            f"{subset_renaming.get(subset, subset)}\n{sample_size_str}",
            x=1.0,
            y=1.05,
        )
        #plt.savefig("top_features.pdf", bbox_inches="tight")
        plt.show()

# %%
subset_renaming = {
    "non_coding_AND_600886": "Hyperferritinemia",
    "non_coding_AND_613985": "Beta-thalassemia",
    "non_coding_AND_614743": "Pulmonary fibrosis",
    "non_coding_AND_306900": "Hemophilia B",
    "non_coding_AND_250250": "Cartilage-hair hypoplasia",
    "non_coding_AND_174500": "Preaxial polydactyly II",
    "non_coding_AND_143890": "Hypercholesterolemia-1",
    "non_coding_AND_210710": "Dwarfism (MOPD1)",

    "non_coding_AND_Mono": "Monocyte count",
    "non_coding_AND_HbA1c": "Hemoglobin A1c",
    "non_coding_AND_HDLC": "High density lipoprotein cholesterol",
}

# %%
enformer_metadata = pd.read_csv(
    "../../results/metadata/Enformer.csv",
    usecols=["name", "description", "assay", "sample"],
)
enformer_metadata
# Out:
#              name                                        description  assay  \
# 0     ENCFF833POA  DNASE:cerebellum male adult (27 years) and mal...  DNASE
# 1     ENCFF110QGM  DNASE:frontal cortex male adult (27 years) and...  DNASE
# 2     ENCFF880MKD                                      DNASE:chorion  DNASE
# 3     ENCFF463ZLQ  DNASE:Ishikawa treated with 0.02% dimethyl sul...  DNASE
# 4     ENCFF890OGQ                                      DNASE:GM03348  DNASE
# ...           ...                                                ...    ...
# 5308    CNhs14239        CAGE:epithelioid sarcoma cell line:HS-ES-2R   CAGE
# 5309    CNhs14240  CAGE:squamous cell lung carcinoma cell line:RE...   CAGE
# 5310    CNhs14241                  CAGE:gastric cancer cell line:GSS   CAGE
# 5311    CNhs14244                  CAGE:carcinoid cell line:NCI-H727   CAGE
# 5312    CNhs14245  CAGE:lung adenocarcinoma, papillary cell line:...   CAGE
#
#                                                  sample
# 0     cerebellum male adult (27 years) and male adul...
# 1     frontal cortex male adult (27 years) and male ...
# 2                                               chorion
# 3     Ishikawa treated with 0.02% dimethyl sulfoxide...
# 4                                               GM03348
# ...                                                 ...
# 5308             epithelioid sarcoma cell line:HS-ES-2R
# 5309  squamous cell lung carcinoma cell line:RERF-LC-AI
# 5310                       gastric cancer cell line:GSS
# 5311                       carcinoid cell line:NCI-H727
# 5312  lung adenocarcinoma, papillary cell line:NCI-H441
#
# [5313 rows x 4 columns]

# %%
borzoi_metadata = pd.read_csv(
    "../../results/metadata/Borzoi.csv", usecols=["name", "description", "assay", "sample"]
)
borzoi_metadata
# Out:
#                             name  \
# 0                     CNhs10608+
# 1                     CNhs10608-
# 2                     CNhs10610+
# 3                     CNhs10610-
# 4                     CNhs10612+
# ...                          ...
# 7606  GTEX-13FTX-1026-SM-5J2O5.1
# 7607  GTEX-1MA7W-1526-SM-DHXKS.1
# 7608  GTEX-11EMC-1926-SM-5A5JU.1
# 7609  GTEX-12WSB-2426-SM-5EGJC.1
# 7610   GTEX-W5WG-1026-SM-4LMIF.1
#
#                                             description assay  \
# 0     CAGE:Clontech Human Universal Reference Total ...  CAGE
# 1     CAGE:Clontech Human Universal Reference Total ...  CAGE
# 2     CAGE:SABiosciences XpressRef Human Universal T...  CAGE
# 3     CAGE:SABiosciences XpressRef Human Universal T...  CAGE
# 4     CAGE:Universal RNA - Human Normal Tissues Bioc...  CAGE
# ...                                                 ...   ...
# 7606                                         RNA:uterus   RNA
# 7607                                         RNA:uterus   RNA
# 7608                                         RNA:vagina   RNA
# 7609                                         RNA:vagina   RNA
# 7610                                         RNA:vagina   RNA
#
#                                                  sample
# 0     Clontech Human Universal Reference Total RNA, ...
# 1     Clontech Human Universal Reference Total RNA, ...
# 2     SABiosciences XpressRef Human Universal Total ...
# 3     SABiosciences XpressRef Human Universal Total ...
# 4     Universal RNA - Human Normal Tissues Biochain,...
# ...                                                 ...
# 7606                                             uterus
# 7607                                             uterus
# 7608                                             vagina
# 7609                                             vagina
# 7610                                             vagina
#
# [7611 rows x 4 columns]

# %%
#dataset = "mendelian_matched_9"
#subsets = [
#    "non_coding_AND_613985",  # Beta-thalassemia
#    #"non_coding_AND_614743",
#    "non_coding_AND_306900",  # Hemophilia B
#    #"non_coding_AND_250250",
#    "non_coding_AND_143890",  # Hypercholesterolemia-1
#]

dataset = "gwas_matched_9"
subsets = [
    "non_coding_AND_Mono",
    "non_coding_AND_HbA1c",
    "non_coding_AND_HDLC",
    #"non_coding_AND_Alb",
    #"non_coding_AND_DVT",
]

base_dir = f"../../results/dataset/{dataset}"
V = pd.read_parquet(f"{base_dir}/test.parquet")

# %% [markdown]
# ## Marginal performance

# %%
models = pd.DataFrame(
    [
        ["Enformer", "Enformer_L2", "C0"],
        ["Borzoi", "Borzoi_L2", "C1"],
    ],
    columns=["Model", "path", "color"]
).set_index("Model")
models
# Out:
#                  path color
# Model
# Enformer  Enformer_L2    C0
# Borzoi      Borzoi_L2    C1

# %%
dfs = []
sample_size = {}

for subset in tqdm(subsets):
    s = pd.read_parquet(f"{base_dir}/subset/{subset}.parquet")
    V_s = s.merge(V, on=["chrom", "pos", "ref", "alt"], how="left")
    sample_size[subset] = V_s.label.sum(), (~V_s.label).sum()
    for model in models.index:
        df = pd.read_csv(f"{base_dir}/unsupervised_metrics/{subset}/{models.loc[model, 'path']}.csv")
        if model == "Enformer":
            df = df.merge(enformer_metadata, left_on="feature", right_on="name", how="inner")
            df = df[df.assay.isin(["RNA", "CAGE"])]
            df = df.drop_duplicates("sample")
        elif model == "Borzoi":
            df = df.merge(borzoi_metadata, left_on="feature", right_on="name", how="inner")
            df = df[df.assay.isin(["RNA", "CAGE"])]
            df = df.drop_duplicates("sample")
        df = df.head(30)
        df["subset"] = subset_renaming.get(subset, subset)
        df["Model"] = model
        dfs.append(df)
df = pd.concat(dfs)
df
# Out:
# 100%|██████████████████████████████████████████████| 3/3 [00:00<00:00, 18.51it/s]
#         AUPRC       feature          name  \
# 5    0.557506     CNhs10852     CNhs10852
# 7    0.553407     CNhs13475     CNhs13475
# 8    0.551956     CNhs13483     CNhs13483
# 10   0.548486     CNhs13488     CNhs13488
# 11   0.547704     CNhs13532     CNhs13532
# ..        ...           ...           ...
# 573  0.309830  ENCFF643UKE-  ENCFF643UKE-
# 597  0.308383    CNhs12328-    CNhs12328-
# 608  0.307394    CNhs11062-    CNhs11062-
# 614  0.306492    CNhs12195-    CNhs12195-
# 636  0.304906  ENCFF841GMC-  ENCFF841GMC-
#
#                                            description assay  \
# 5                                CAGE:CD14+ Monocytes,  CAGE
# 7             CAGE:CD14+ monocytes - treated with BCG,  CAGE
# 8    CAGE:CD14+ monocytes - treated with Trehalose ...  CAGE
# 10        CAGE:CD14+ monocytes - treated with Candida,  CAGE
# 11   CAGE:CD14+ monocytes - treated with Group A st...  CAGE
# ..                                                 ...   ...
# 573            RNA:spleen tissue male adult (37 years)   RNA
# 597  CAGE:hepatocellular carcinoma cell line: HepG2...  CAGE
# 608  CAGE:Dendritic Cells - monocyte immature deriv...  CAGE
# 614  CAGE:Dendritic Cells - monocyte immature derived,  CAGE
# 636      RNA:hematopoietic multipotent progenitor cell   RNA
#
#                                                 sample  \
# 5                                     CD14+ Monocytes,
# 7                  CD14+ monocytes - treated with BCG,
# 8    CD14+ monocytes - treated with Trehalose dimyc...
# 10             CD14+ monocytes - treated with Candida,
# 11   CD14+ monocytes - treated with Group A strepto...
# ..                                                 ...
# 573                spleen tissue male adult (37 years)
# 597  hepatocellular carcinoma cell line: HepG2 ENCO...
# 608  Dendritic Cells - monocyte immature derived, ,...
# 614       Dendritic Cells - monocyte immature derived,
# 636          hematopoietic multipotent progenitor cell
#
#                                    subset     Model
# 5                          Monocyte count  Enformer
# 7                          Monocyte count  Enformer
# 8                          Monocyte count  Enformer
# 10                         Monocyte count  Enformer
# 11                         Monocyte count  Enformer
# ..                                    ...       ...
# 573  High density lipoprotein cholesterol    Borzoi
# 597  High density lipoprotein cholesterol    Borzoi
# 608  High density lipoprotein cholesterol    Borzoi
# 614  High density lipoprotein cholesterol    Borzoi
# 636  High density lipoprotein cholesterol    Borzoi
#
# [180 rows x 8 columns]

# %%
for subset in df.subset.unique():
    print(subset)
    for model in df.Model.unique():
        print(model)
        df2 = df[(df.subset==subset) & (df.Model==model)]
        print(df2[["AUPRC", "sample"]].values)
# Out:
# Monocyte count
# Enformer
# [[0.5575056900181379 'CD14+ Monocytes,']
#  [0.553407430896893 'CD14+ monocytes - treated with BCG,']
#  [0.5519562307877873
#   'CD14+ monocytes - treated with Trehalose dimycolate (TDM),']
#  [0.5484858468486936 'CD14+ monocytes - treated with Candida,']
#  [0.5477039854067974
#   'CD14+ monocytes - treated with Group A streptococci,']
#  [0.5441841878348003 'CD14+CD16+ Monocytes,']
#  [0.5414147891748046 'Basophils,']
#  [0.5413346969887541 'CD14+CD16- Monocytes,']
#  [0.5400793643610309 'CD14+ monocytes - treated with lipopolysaccharide,']
#  [0.5377562561485341 'CD14+ monocytes - treated with Cryptococcus,']
#  [0.5356152004566095 'CD14+ monocytes - treated with B-glucan,']
#  [0.5292521666142148 'CD14-CD16+ Monocytes,']
#  [0.5277392387183522 'CD14+ monocytes - treated with Salmonella,']
#  [0.5271750254239144 'CD14+ monocytes - treated with IFN + N-hexane,']
#  [0.524208618956415 'CD14+ monocytes - mock treated,']
#  [0.5138705446091504 'Peripheral Blood Mononuclear Cells,']
#  [0.5034658700316236 'Neutrophils,']
#  [0.4875746581135514 'Eosinophils,']
#  [0.4635251580821989 'immature langerhans cells,']
#  [0.4587735699682445
#   'acute myeloid leukemia (FAB M5) cell line:U-937 DE-4']
#  [0.458632973605142 'Mast cell,']
#  [0.4526072324594051 'Macrophage - monocyte derived,']
#  [0.4524313575091513 'Whole blood (ribopure), , donation1']
#  [0.4429998089678492 'Whole blood (ribopure), , donation2']
#  [0.4428486845752638
#   'CD14+ monocyte derived endothelial progenitor cells,']
#  [0.4389762867135894 'Dendritic Cells - monocyte immature derived,']
#  [0.438490360379541 'acute myeloid leukemia (FAB M2) cell line:NKM-1']
#  [0.4334379357278991 'acute myeloid leukemia (FAB M4eo) cell line:EoL-3']
#  [0.4327722776483293 'acute myeloid leukemia (FAB M4eo) cell line:EoL-1']
#  [0.4298962468497085
#   'biphenotypic B myelomonocytic leukemia cell line:MV-4-11']]
# Borzoi
# [[0.5594197731790993 'CD14+ monocytes - treated with BCG,']
#  [0.5565096595616823
#   'CD14+ monocytes - treated with Trehalose dimycolate (TDM),']
#  [0.5559008678844445 'Neutrophils,']
#  [0.5547687078340207
#   'CD14+ monocytes - treated with Group A streptococci,']
#  [0.5539842593614636 'CD14+ monocytes - treated with Candida,']
#  [0.5513570010354896 'CD14+ Monocytes,']
#  [0.5509086358972433 'CD14+ monocytes - treated with Salmonella,']
#  [0.5472064606151904 'CD14+ monocytes - treated with lipopolysaccharide,']
#  [0.5459859946116948 'CD14+ monocytes - treated with Cryptococcus,']
#  [0.5442307897286576 'CD14+ monocytes - treated with B-glucan,']
#  [0.54213111514947 'CD14+CD16+ Monocytes,']
#  [0.5415184948087098 'CD14+ monocytes - treated with IFN + N-hexane,']
#  [0.5359236596332505 'CD14+CD16- Monocytes,']
#  [0.5357601719663613 'CD14-positive monocyte male adult (37 years)']
#  [0.5345085527558937 'CD14+ monocytes - mock treated,']
#  [0.5315993717793783 'Basophils,']
#  [0.5306013198418855 'Eosinophils,']
#  [0.5252345884517514 'CD14-CD16+ Monocytes,']
#  [0.5135122422383923 'Peripheral Blood Mononuclear Cells,']
#  [0.5088388272970925 'CD14-positive monocyte female']
#  [0.5017474464453503 'with multiple sclerosis; CD14-positive monocyte']
#  [0.5005550524511823 'CD14-positive monocyte']
#  [0.4808833321745096 'mononuclear cell female adult (52 years)']
#  [0.4788227165194421 'Macrophage - monocyte derived,']
#  [0.4750061679649707
#   'peripheral blood mononuclear cell male adult (39 years)']
#  [0.4723215812874703 'blood']
#  [0.4711234728626389 'immature langerhans cells,']
#  [0.4703126560271464 'CD34+ Progenitors,']
#  [0.4644805078447407 'Whole blood (ribopure), , donation2']
#  [0.4624341343470187 'Whole blood (ribopure), , donation1']]
# Hemoglobin A1c
# Enformer
# [[0.4260126425896789
#   'CD34 cells differentiated to erythrocyte lineage, biol_']
#  [0.381365590476297 'chronic myelogenous leukemia cell line:KU812']
#  [0.3734325988935768 'acute myeloid leukemia (FAB M6) cell line:F-36P']
#  [0.3692696416436286
#   'leukemia, chronic megakaryoblastic cell line:MEG-01']
#  [0.3668856786317571
#   'chronic myelogenous leukemia (CML) cell line:MEG-A2']
#  [0.3598152862068083 'acute myeloid leukemia (FAB M6) cell line:EEB']
#  [0.355855390139511 'Whole blood (ribopure), , donation3']
#  [0.3549467648392775 'spleen, fetal, pool1']
#  [0.3527764256348984 'acute myeloid leukemia (FAB M7) cell line:MKPL-1']
#  [0.3505563474979538
#   'chronic myelogenous leukemia cell line:K562 ENCODE, biol_']
#  [0.3478427492694552 'Whole blood (ribopure), , donation2']
#  [0.3467385851619471 'Whole blood (ribopure), , donation1']
#  [0.3460956231592678 'liver, fetal, pool1']
#  [0.3384659427541369 'acute myeloid leukemia (FAB M6) cell line:F-36E']
#  [0.338095738430763 'blood, adult, pool1']
#  [0.3297232713737963 'chronic myelogenous leukemia cell line:K562']
#  [0.3160616187855805 'acute myeloid leukemia (FAB M7) cell line:M-MOK']
#  [0.3093732880281005
#   'CD34+ stem cells - adult bone marrow derived, , tech_']
#  [0.2892463672263461
#   'chronic myeloblastic leukemia (CML) cell line:KCL-22']
#  [0.2881098447896947 'Neutrophils,']
#  [0.2788418203346105 'lung, fetal,']
#  [0.2783697071428591 'Mast cell - stimulated,']
#  [0.2728894645834661 'CD34+ Progenitors,']
#  [0.2643365930774443 'CD14+ monocytes - mock treated,']
#  [0.2631110643510144 'Mast cell, expanded,']
#  [0.2627435167190232 'Mast cell,']
#  [0.2627328352779005 'immature langerhans cells,']
#  [0.26052914786576 'adult T-cell leukemia cell line:ATN-1']
#  [0.260009674392088 'mature adipocyte,']
#  [0.2578115837281298 'migratory langerhans cells,']]
# Borzoi
# [[0.4008598618342636 'K562 treated with Interferon gamma for 6 hours']
#  [0.3983987342647657 'K562 treated with interferon alpha for 6 hours']
#  [0.3905950683506004 'K562 treated with Interferon gamma for 30 minutes']
#  [0.3868783267155321 'K562 treated with interferon alpha for 30 minutes']
#  [0.3758644777399857 'K562']
#  [0.375507220584164 'K562 nucleolus fraction']
#  [0.3735829427700973 'K562 membrane fraction']
#  [0.3731717107640117
#   'CD34 cells differentiated to erythrocyte lineage, biol_']
#  [0.3704239392976349 'K562 treated with 50 uM C646 for 12 hours']
#  [0.3702761728254558 'K562 nuclear fraction']
#  [0.3700010540692727 'K562 chromatin fraction']
#  [0.3697422788190733 'K562 nucleoplasmic fraction']
#  [0.3683683720088871 'K562 cytosolic fraction']
#  [0.3649424636412213 'K562 treated with 50 uM C646 for 4 hours']
#  [0.359441567216824 'bone_marrow']
#  [0.3553032718886787 'K562 treated with 5 uM JQ1 for 4 hours']
#  [0.3537219381844699 'K562 treated with 1% DMSO for 12 hours']
#  [0.3528352057839908 'K562 treated with 50 uM C646 for 24 hours']
#  [0.3523615506946509 'K562 treated with 7.5 nM Vorinostat for 48 hours']
#  [0.3520150065635485 'K562 treated with 1% DMSO for 4 hours']
#  [0.3513174090942594 'K562 insoluble cytoplasmic fraction']
#  [0.3507411326112852 'K562 treated with 7.5 nM Vorinostat for 4 hours']
#  [0.3498775059457113 'K562 treated with 10 uM Crizotinib for 4 hours']
#  [0.3490782963624855 'K562 treated with 7.5 nM Panobinostat for 4 hours']
#  [0.3485765707258816 'K562 treated with 7.5 nM Panobinostat for 12 hours']
#  [0.3470047898159963 'K562 treated with 100 nM GSK J4 for 24 hours']
#  [0.3467671177904323 'K562 treated with 7.5 nM Vorinostat for 24 hours']
#  [0.3464252118949913 'K562 treated with 100 nM GSK J4 for 4 hours']
#  [0.345474679360662 'K562 treated with 1% DMSO for 24 hours']
#  [0.3439494819229154 'K562 treated with 10 nM Chaetocin for 4 hours']]
# High density lipoprotein cholesterol
# Enformer
# [[0.3340695991785115
#   'Universal RNA - Human Normal Tissues Biochain, pool1']
#  [0.3331556681144001 'liver, adult, pool1']
#  [0.3330742193770273
#   'SABiosciences XpressRef Human Universal Total RNA, pool1']
#  [0.331524524586249 'Hepatocyte,']
#  [0.3289270202609757
#   'CD14+ monocytes - treated with Trehalose dimycolate (TDM),']
#  [0.3233062440612883 'mature adipocyte,']
#  [0.3226699221736871 'CD14+ monocytes - treated with IFN + N-hexane,']
#  [0.3226252934418044 'CD14+ monocytes - treated with BCG,']
#  [0.3215426267956204 'Macrophage - monocyte derived,']
#  [0.3140698038386717 'CD14+ monocytes - treated with Cryptococcus,']
#  [0.3118202944351183 'CD14+ monocytes - treated with B-glucan,']
#  [0.3114332708138909
#   'CD14+ monocyte derived endothelial progenitor cells,']
#  [0.3103049262138668 'liver, fetal, pool1']
#  [0.3097853980138758 'CD14+ monocytes - treated with Salmonella,']
#  [0.3022375172413339 'Dendritic Cells - monocyte immature derived,']
#  [0.3021263177403419 'CD14+ monocytes - treated with Candida,']
#  [0.3004425041153479 'CD14+ monocytes - mock treated,']
#  [0.2962003727038559 'CD14-CD16+ Monocytes,']
#  [0.2959772190217396
#   'hepatocellular carcinoma cell line: HepG2 ENCODE, biol_']
#  [0.2939643159648803 'CD14+ monocytes - treated with lipopolysaccharide,']
#  [0.2933852840841865
#   'CD14+ monocytes - treated with Group A streptococci,']
#  [0.2909990503572015 'CD14+CD16+ Monocytes,']
#  [0.2899345309942679 'CD14+ Monocytes,']
#  [0.2862553508212856 'CD14+CD16- Monocytes,']
#  [0.285358755579884
#   'Dendritic Cells - monocyte immature derived, , tech_']
#  [0.2804940401050212 'Basophils,']
#  [0.2775152012530962 'acute myeloid leukemia (FAB M0) cell line:KG-1']
#  [0.2759823796778276 'immature langerhans cells,']
#  [0.2755330773645053 'acute myeloid leukemia (FAB M2) cell line:NKM-1']
#  [0.2740011667733647
#   'acute myeloid leukemia (FAB M5) cell line:U-937 DE-4']]
# Borzoi
# [[0.3710434294672896
#   'liver tissue female child (4 years) and with nonobstructive coronary artery disease; liver tissue male adult (32 years)']
#  [0.3621399135780974 'left lobe of liver tissue male adult (45 years)']
#  [0.3604707847604855 'Hepatocyte,']
#  [0.358722591299637 'liver, fetal, pool1']
#  [0.3586212067270065 'right lobe of liver tissue female child (16 years)']
#  [0.3577308191363322 'HepG2 cytosolic fraction']
#  [0.3573288537589026 'right lobe of liver tissue female adult (41 years)']
#  [0.3514000248928948
#   'liver tissue female child (6 years) and with nonobstructive coronary artery disease; liver tissue male adult (32 years)']
#  [0.3512781862044077 'HepG2 membrane fraction']
#  [0.3477492524456397 'liver']
#  [0.3458789393442176 'right lobe of liver tissue female adult (47 years)']
#  [0.3432683061221487 'liver tissue male adult (18 years)']
#  [0.3384914302607877 'liver, adult, pool1']
#  [0.3358603058040602 'liver tissue male child (3 years)']
#  [0.3348053228820686 'right lobe of liver tissue female adult (53 years)']
#  [0.3322213080851208
#   'liver tissue female embryo (20 weeks) and male embryo (22 weeks)']
#  [0.3247387512357169 'mature adipocyte,']
#  [0.3228064976875655
#   'peripheral blood mononuclear cell female adult (28 years)']
#  [0.318294776215391
#   'SABiosciences XpressRef Human Universal Total RNA, pool1']
#  [0.317255998676714 'HepG2']
#  [0.3154629493028758
#   'Universal RNA - Human Normal Tissues Biochain, pool1']
#  [0.3124064300490619 'HepG2 nuclear fraction']
#  [0.3120376188132033
#   'CD14+ monocyte derived endothelial progenitor cells,']
#  [0.3111256244982693 'Macrophage - monocyte derived,']
#  [0.3110680154821761
#   'peripheral blood mononuclear cell male adult (39 years)']
#  [0.3098304125197111 'spleen tissue male adult (37 years)']
#  [0.3083827880440243
#   'hepatocellular carcinoma cell line: HepG2 ENCODE, biol_']
#  [0.3073935723056648
#   'Dendritic Cells - monocyte immature derived, , tech_']
#  [0.3064915328702169 'Dendritic Cells - monocyte immature derived,']
#  [0.3049055109969792 'hematopoietic multipotent progenitor cell']]

# %%
# Mendelian
make_plots()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[128], line 2
#       1 # Mendelian
# ----> 2 make_plots()
#
# Cell In[62], line 30, in make_plots()
#      28 elif metric == "Odds ratio":
#      29     baseline = 1
# ---> 30 g = sns.catplot(
#      31     data=df[df.subset==subset],
#      32     y="feature",
#      33     x=metric,
#      34     row="Model",
#      35     sharex=True,
#      36     sharey=False,
#      37     kind="bar",
#      38     color="C0",
#      39     height=3,
#      40     aspect=2,
#      41 )
#      42 g.set(
#      43     xlim=baseline,
#      44     ylabel="",
#      45 )
#      46 g.set_titles("{row_name}")
#
# File /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/categorical.py:3211, in catplot(data, x, y, hue, row, col, col_wrap, estimator, errorbar, n_boot, units, seed, order, hue_order, row_order, col_order, height, aspect, kind, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    3205 hue_order = p.hue_names
#    3207 # Determine the palette to use
#    3208 # (FacetGrid will pass a value for ``color`` to the plotting function
#    3209 # so we need to define ``palette`` to get default behavior for the
#    3210 # categorical functions
# -> 3211 p.establish_colors(color, palette, 1)
#    3212 if kind != "point" or hue is not None:
#    3213     palette = p.colors
#
# File /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/categorical.py:707, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     705 # Determine the gray color to use for the lines framing the plot
#     706 light_vals = [rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 707 lum = min(light_vals) * .6
#     708 gray = mpl.colors.rgb2hex((lum, lum, lum))
#     710 # Assign object attributes
#
# ValueError: min() arg is an empty sequence
